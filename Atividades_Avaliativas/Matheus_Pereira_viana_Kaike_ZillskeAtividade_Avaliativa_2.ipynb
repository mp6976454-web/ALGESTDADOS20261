# %% [markdown]
# <a href="https://colab.research.google.com/github/mp6976454-web/ALGESTDADOS20261/blob/main/Atividades_Avaliativas/Matheus_Pereira_viana_Kaike_ZillskeAtividade_Avaliativa_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#01

somatorio = 0
ticket_alto = 0
maior_salario = 0 # Renamed for clarity and initialized to 0

for i in range(1,11): # Changed loop variable to 'i' to avoid confusion with 'salario' input

        soldo = int(input('DIgite o salário'))

        if soldo > 0:

            somatorio+= soldo
            media = somatorio/i # Use 'i' as the counter for media calculation

            if soldo > 3000:
                    ticket_alto+= soldo

            # Correctly track the maximum 'soldo' (salary input)
            if soldo > maior_salario:
                    maior_salario = soldo


        else:
            print('valores inválidos')



print(f'A media dos valores pagos ao funcionários é de {media}')
print(f'O maior salário encontrado é de {maior_salario}') # Changed to maior_salario
print(f'Ja a soma dos salários acima de R$3000,00 é de {ticket_alto}')

# %%
#02

somatorio = 0
aprovados = 0
reprovados = 0
contador_notas_validas = 0

while True:

    nota_digitada = int(input('Digite a nota (ou -1 para finalizar): '))

    if nota_digitada == -1:
        break
    if nota_digitada < 0:
        print('Valor inválido: a nota não pode ser negativa.')
        continue

    somatorio += nota_digitada
    contador_notas_validas += 1

    if nota_digitada >= 7:
        aprovados += 1
    elif 0 <= nota_digitada < 7:

        reprovados += 1

if contador_notas_validas > 0:
    media = somatorio / contador_notas_validas
else:
    media = 0
print(f'A média da turma é igual a {media:.2f}') # Formata a média para duas casas decimais
print(f'A quantidade de alunos aprovados é igual a {aprovados}\nE a de reprovados {reprovados}')

# %%
#03

# O programa deve iniciar com um saldo informado pelo usuário e permitir saques sucessivos até que seja digitado 0

saldo = float(input('Digite o saldo presente em conta'))

#O programa deve iniciar com um saldo informado pelo usuário e permitir saques sucessivos até que seja digitado 0.
# A cada tentativa, verifique se há saldo suficiente
# atualize o saldo quando possível e informe ao usuário quando o valor exceder o saldo disponível.
contador = 0
while True:


    saque = float(input('Digite valor a ser sacado'))
    if 0 < saque < saldo:

        contador+= saque
        saldo_atual = contador - saldo
        print('saldo suficiente')
        print(f'Saldo atual é de {saldo_atual}')

    elif saque > saldo:
        print('saldo insuficiente para completar a operação')

    elif saque == 0 :
        break

# %%
#04

somatorio = 0
maior_idade = 0
somatorio_18 = 0
idade_valida = 0

while True:

    idade_digitada = int(input('Digite sua idade'))

    if idade_digitada == 0:
        break
    elif idade_digitada < 0:
        print('valor inválido')

    elif idade_digitada > 0:

        somatorio+= idade_digitada
        idade_valida+= 1


    if idade_digitada > 18:
        somatorio_18+= 1

    if idade_digitada > maior_idade:
        maior_idade = idade_digitada

if idade_valida > 0:
    media = somatorio/idade_valida
else:
    media = 0

print(f'A media de idade do grupo é de {media}\nA maior idade registrada é de {maior_idade}\nJá a quantidade de pessoas maiores de 18 é de {somatorio_18}')

# %%
#05

senha_correta = 2024
contador = 0

for acesso in range(1,4):
    tentativa = int(input('digite a senha'))

    contador+= 1
    print(f'{contador} tentativa usada (limite: 3)')

if tentativa != senha_correta:
    print('Acesso bloqueado!!! Senha incorreta')
elif tentativa == senha_correta:
    print('Acesso liberado')

# %%
#06


soma_venda = 0
soma_venda_bruta = 0

for operacao in range(1,9):

    venda = float(input('Digite o valor arrecadado na venda'))

    if venda > 100:

        desconto = 0.10
        soma_venda+= venda
        liquido = soma_venda - (soma_venda*0.10)

    elif 100 > venda > 0:

        soma_venda_bruta+= venda

    else:
        print('Valores inválidos')

print(f'O valor arrecadado é de {liquido + soma_venda_bruta}')

# %%
#07

soma_positivo = 0
soma_pares = 0
soma_impares = 0

while True:

    numero_digitado = float(input('Digite um numero'))

    if numero_digitado == 0:
        break

    elif numero_digitado % 2 == 0:

        soma_pares+= 1

        if numero_digitado > 0:

            soma_positivo+= 1

    elif numero_digitado % 2 !=0:

        soma_impares+= 1

        if numero_digitado > 0:

            soma_positivo+= 1


print(f'A sequencia numérica possui {soma_positivo} numeros positivos\n{soma_pares}números pares\n{soma_impares}números impares')

# %%
#08

somatorio = 0
soma = 0
soma_oitenta = 0
menor_valor =

for alunos in range(1,9)
    peso_coletado = float(input('digite o peso coletado'))

    if peso_coletado > 0:

        somatorio+= 1
        soma+= peso_coletado

        if peso_coletado > 0:

            soma_oitenta+= 1

    if alunos == 1:
        menor_valor = peso_coletado


if somatorio > 0:
    media = peso_coletado/somatorio
    print(f'Media igual a {media:.2f}')
else:
    media = 0

print(f'O menor peso encontrado foi de {menor_valor:.2f}')

# %%
#09

soma_um = 0
soma_dois = 0
soma_tres = 0

maior_voto = 0

while True:

    votos_selecionados = int(input(('Digite 1 para Tirulipa. Digite 2 para Tiringa. Digite 3 Para Thanos')))

    if votos_selecionados == 1:
        soma_um+= 1
    elif votos_selecionados == 2:
        soma_dois+= 1
    elif votos_selecionados == 3:
        soma_tres+= 1
    elif votos_selecionados == 0:
      break
    else:
        print('valores inválidos')
        break

if soma_um > soma_dois or soma_tres:
    print('\nCandidato com maior numero de votos é Tirulipa')
elif soma_dois > soma_um or soma_tres:
    print('\ncandidato com maior numero de votos é Tiringa')
elif soma_tres > soma_dois or soma_um:
    print('\nCandidato com maior numero de votos é Thanos')

# %%
11
#10

somatorio = 0
baixa_produção = 0

for produção in range(1,8):
    produzido = int(input('Digite a quantidade de peças produzidas'))

    if produzido < 0:
        print('valor inválido, digite de novo os valores agora corretos')
        break
    if produzido >= 0 :
        somatorio+= produzido
    if 100 > produzido:
        baixa_produção+= 1

media = somatorio/7
print(f'A media de atingida pela produção foi de {media:.2f} durante 7 dias')
print(f'A produção não alcançou 100 unidades {baixa_produção} vezes!')

# %%
3#11

somatorio = 0
soma_multiplo = 0

while True:

    valores = int(input('digite valores'))
    if valores == -1:
        print('seção incerrada');
        break

    if valores % 3 == 0:
        soma_multiplo+= 1
        somatorio+= valores

if soma_multiplo != 0:

    media = somatorio/soma_multiplo
    print(f'A media dos multiplos de três {media:.2f}')
    print(f'A quantidade de multiplos é {soma_multiplo}')

# %%
#12

somatorio = 0
soma_altura = 0
soma_desvio = 0

for alunos in range(1,4):

    altura = float(input('Digite a altura do aluno'))
    somatorio+= 1
    soma_altura+= altura

if somatorio > 0:
    media = soma_altura/somatorio
    print(f'A media das alturas na sala é de {media:.2f}')

    if altura > media:
        soma_desvio+= 1
        print(f'Existe {soma_desvio} acima da media')

# %%
#13

somatorio = 0
soma_operaçao = 0
maior_deposito = 0

while True:

    deposito = float(input('Digite o valor a ser depositado. Tecle 0 para encerrar seção'))
    if deposito == 0:
        print('Seção encerrada')
        break

    elif deposito > 0:

        somatorio+= deposito
        soma_operaçao+= 1

    else:
        print('valores inválidos')



    if deposito > maior_deposito:

        maior_deposito = deposito


print(f'A quantia depositada é de {somatorio}\nO numero de depositos feitos é de {soma_operaçao}')
print(f'O maior deposito realizado foi de {maior_deposito}')

# %%
#14

numero = int(input('Digite um numero inteiro'))

divisores = 0

print(f'Os divisores de {numero}')

for i in range(1, numero + 1):

    if numero % i == 0:
        print(i)

        divisores+= 1

print(f'A quantidade de divisores para {numero} é {divisores}')

if divisores == 2:

    print('O numero digitado é primo: ele só devide por um e por ele mesmo')

else:

    print('O numero não é primo: ele divide por mais numeros ')

# %%
#15

soma = 0
soma_menor = 0

while True:

  preco = float(input('DIgite valore da venda'))
  if preco == 0:
      break

  if preco > 200:

      desconto = preco * 0.05
      liquido = preco - desconto

      soma+= liquido

  if 200 >= preco > 0:

      soma_menor+= preco


print(f'O valor total a ser pago é {soma+soma_menor}')

# %%
# ============================================
# 16 - Tempo de Atendimento
# ============================================

tempo = float(input('Tempo de atendimento (0 encerra): '))

clientes = 0
soma = 0

while tempo != 0:
    soma += tempo
    clientes += 1

    tempo = float(input('Tempo de atendimento (0 encerra): '))

if clientes > 0:
    media = soma / clientes
else:
    media = 0

print('Total de clientes atendidos:', clientes)
print('Tempo medio de atendimento:', round(media, 2))

# %%
# ============================================
# 17 - Análise de 10 Números
# ============================================

i = 1

negativos = 0
soma_positivos = 0

num = int(input('Digite um numero: '))
maior = num

while i <= 10:
    if num < 0:
        negativos += 1
    else:
        soma_positivos += num

    if num > maior:
        maior = num

    i += 1

    if i <= 10:
        num = int(input('Digite um numero: '))

print('Quantidade de negativos:', negativos)
print('Soma dos positivos:', soma_positivos)
print('Maior valor:', maior)

# %%
# ============================================
# 18 - Consumo de Energia
# ============================================

i = 1
total = 0

while i <= 6:
    consumo = float(input('Consumo da residencia: '))

    if consumo > 100:
        valor = consumo * 0.80
    else:
        valor = consumo * 0.50

    total += valor

    i += 1

print('Total arrecadado: R$', round(total, 2))

# %%
# ============================================
# 19 - Adivinhe o Número Secreto
# ============================================

secreto = 7

tentativa = int(input('Digite um numero: '))

tentativas = 1

while tentativa != secreto:
    if tentativa > secreto:
        print('O numero secreto e menor')
    else:
        print('O numero secreto e maior')

    tentativa = int(input('Digite um numero: '))
    tentativas += 1

print('Numero correto!')
print('Quantidade de tentativas:', tentativas)

# %%
# ============================================
# 20 - Estatísticas de Notas
# ============================================

nota = float(input('Digite uma nota (-1 encerra): '))

soma = 0
cont = 0
maior = 0

while nota != -1:
    soma += nota
    cont += 1

    if nota > maior:
        maior = nota

    nota = float(input('Digite uma nota (-1 encerra): '))

if cont > 0:
    media = soma / cont
else:
    media = 0

nota = float(input('Digite novamente as notas para verificar abaixo da media (-1 encerra): '))

abaixo = 0

while nota != -1:
    if nota < media:
        abaixo += 1

    nota = float(input('Digite novamente as notas para verificar abaixo da media (-1 encerra): '))

print('Media:', round(media, 2))
print('Maior nota:', maior)
print('Notas abaixo da media:', abaixo)

# %%
# ============================================
# 21 - Pesquisa Eleitoral
# ============================================

voto = int(input('Digite o voto (0 encerra): '))

c1 = 0
c2 = 0
c3 = 0
invalidos = 0

while voto != 0:
    if voto == 1:
        c1 += 1
    elif voto == 2:
        c2 += 1
    elif voto == 3:
        c3 += 1
    else:
        invalidos += 1

    voto = int(input('Digite o voto (0 encerra): '))

validos = c1 + c2 + c3

if c1 > c2 and c1 > c3:
    vencedor = 1
elif c2 > c1 and c2 > c3:
    vencedor = 2
else:
    vencedor = 3

print('Votos validos:', validos)
print('Votos invalidos:', invalidos)
print('Candidato vencedor:', vencedor)

# %%
# ============================================
# 22 - Estacionamento
# ============================================

tempo = float(input('Tempo de permanencia (0 encerra): '))

total = 0

while tempo != 0:
    valor = tempo * 10

    if tempo > 5:
        valor = valor - (valor * 0.10)

    total += valor

    tempo = float(input('Tempo de permanencia (0 encerra): '))

print('Total arrecadado: R$', round(total, 2))

# %%
# ============================================
# 23 - Divisíveis por 2 e por 3
# ============================================

num = int(input('Digite um numero (0 encerra): '))

cont = 0
soma = 0
quantidade = 0

while num != 0:
    if num % 2 == 0 and num % 3 == 0:
        cont += 1

    soma += num
    quantidade += 1

    num = int(input('Digite um numero (0 encerra): '))

if quantidade > 0:
    media = soma / quantidade
else:
    media = 0

print('Quantidade divisivel por 2 e 3:', cont)
print('Media dos numeros:', round(media, 2))

# %%
# ============================================
# 24 - Classificação Escolar
# ============================================

i = 1

aprovado = 0
recuperacao = 0
reprovado = 0

while i <= 8:
    media = float(input('Digite a media do aluno: '))

    if media >= 7:
        aprovado += 1
    elif media >= 5:
        recuperacao += 1
    else:
        reprovado += 1

    i += 1

print('Aprovados:', aprovado)
print('Recuperacao:', recuperacao)
print('Reprovados:', reprovado)

# %%
# ============================================
# 25 - Análise de Vendas
# ============================================

venda = float(input('Digite o valor da venda (0 encerra): '))

soma = 0
cont = 0

while venda != 0:
    soma += venda
    cont += 1

    venda = float(input('Digite o valor da venda (0 encerra): '))

if cont > 0:
    media = soma / cont
else:
    media = 0

venda = float(input('Digite novamente as vendas (0 encerra): '))

acima = 0

while venda != 0:
    if venda > media:
        acima += 1

    venda = float(input('Digite novamente as vendas (0 encerra): '))

print('Media das vendas:', round(media, 2))
print('Vendas acima da media:', acima)

# %%
# ============================================
# 26 - Perfil Etário
# ============================================

idade = int(input('Digite a idade (0 encerra): '))

soma = 0
cont = 0
maiores = 0

while idade != 0:
    soma += idade
    cont += 1

    if idade >= 18:
        maiores += 1

    idade = int(input('Digite a idade (0 encerra): '))

if cont > 0:
    media = soma / cont
else:
    media = 0

print('Media das idades:', round(media, 2))
print('Maiores de idade:', maiores)

# %%
# ============================================
# 27 - Par ou Ímpar até N
# ============================================

n = int(input('Digite o valor de N: '))

i = 1

while i <= n:
    if i % 2 == 0:
        print(i, '- Par')
    else:
        print(i, '- Impar')

    i += 1

# %%
# ============================================
# 28 - Caça aos Primos
# ============================================

num = int(input('Digite um numero (-1 encerra): '))

primos = 0
soma = 0

while num != -1:
    i = 1
    divisores = 0

    while i <= num:
        if num % i == 0:
            divisores += 1

        i += 1

    if divisores == 2:
        primos += 1
    else:
        soma += num

    num = int(input('Digite um numero (-1 encerra): '))

print('Quantidade de numeros primos:', primos)
print('Soma dos nao primos:', soma)

# %%
# ============================================
# 29 - Avaliação de Notas
# ============================================

nota = float(input('Digite uma nota (0 encerra): '))

soma = 0
cont = 0

while nota != 0:
    soma += nota
    cont += 1

    nota = float(input('Digite uma nota (0 encerra): '))

if cont > 0:
    media = soma / cont
else:
    media = 0

nota = float(input('Digite novamente as notas (0 encerra): '))

acima = 0

while nota != 0:
    if nota > media:
        acima += 1

    nota = float(input('Digite novamente as notas (0 encerra): '))

print('Media geral:', round(media, 2))
print('Notas acima da media:', acima)

# %%
# ============================================
# 30 - Cálculo de Fatorial
# ============================================

n = int(input('Digite um numero inteiro positivo: '))

fat = 1
i = 1

while i <= n:
    fat = fat * i
    i += 1

print('Fatorial:', fat)

if fat % 2 == 0:
    print('O fatorial e par')
else:
    print('O fatorial e impar')
