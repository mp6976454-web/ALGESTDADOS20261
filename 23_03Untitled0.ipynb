# %% [markdown]
# <a href="https://colab.research.google.com/github/mp6976454-web/ALGESTDADOS20261/blob/main/23_03Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Crie um programa que exiba na tela seu nome e sua idade.

Digite_nome= input("Digite_nome")
print(f"Digite_nome:", Digite_nome)
# Out:
# Digite_nomeMatheus
# Digite_nome: Matheus

# %%
#Faça um programa que peça o nome do usuário e exiba uma mensagem de boas-vindas com o nome digitado.

nomeuser = input("Digite_seu_nome")
print(f"Olá {nomeuser}, seja muito bem-vindo!")
# Out:
# Digite_seu_nomematheus
# Olá matheus, seja muito bem-vindo!

# %%
#Desenvolva um programa que peça dois números ao usuário e mostre a soma entre eles.

num1 = int(input("digite_um_numero"))
num2 = int(input("digite_um_numero"))
soma = num1 + num2
print(f"{num1}+{num2}={soma}")
# Out:
# digite_um_numero21
# digite_um_numero22
# 21+22=43

# %%
#Crie um programa que peça um número inteiro e mostre seu antecessor e seu sucessor

numero = int(input("digite_um_algarismo"))
ant = numero -1
sucess = numero +1
print(f"O antecessor do numero {numero}é igual a {ant}, já o sucessor{sucess} ")
# Out:
# digite_um_algarismo13
# O antecessor do numero 13é igual a 12, já o sucessor14

# %%
#Faça um programa que peça o ano de nascimento do usuário e calcule sua idade aproximada.

Ano = int(input("ano_de_nascimento"))
anoatual = 2026
idade = anoatual - Ano
print(f"A sua idade é {idade}")
# Out:
# ano_de_nascimento1999
# A sua idade é 27

# %%
#Desenvolva um programa que peça duas notas e calcule a média entre elas.
nota1 = float(input("primeira_nota"))
nota2 = float(input("segunda_nota"))
media = (nota1 + nota2)/2
print(f"A media das suas duas notas é {media}")
# Out:
# primeira_nota5.5
# segunda_nota3.3
# A media das suas duas notas é 4.4

# %%
#Crie um programa que peça uma temperatura em graus Celsius e converta para Fahrenheit.

temperatura = float(input("Digite_a_Temperatura_em_graus"))
conversão = ({temperatura}*1,8) +32
print(f"a temperatura em fahrenheit é {conversão}")
# Out:
# Digite_a_Temperatura_em_graus22
# a temperatura em fahrenheit é 71.6

# %%
#Faça um programa que peça a largura e a altura de um retângulo

altura = float(input("digite_altura"))
largura = float(input("digite_largura"))
área = altura*largura
print(f"A área do quadrilatero é {área}")
# Out:
# digite_altura3
# digite_largura4
# A área do quadrilatero é 12.0

# %%
#Desenvolva um programa que peça um número inteiro e calcule o seu quadrado.
numint = float(input("escolha_um_numero_inteiro"))
potencia = numint*numint
print(f"O quadrado do numero escolhido é {potencia}")
# Out:
# escolha_um_numero_inteiro3.1
# O quadrado do numero escolhido é 9.610000000000001

# %%
#Crie uma calculadora simples que peça dois números e uma operação matemática

num1= int(input("digite_o_primeiro_numero"))
num2= int(input("digite_o_segundo_numero"))
operação= input("digite_o_operador (+,-,* ou /:)")
resultado= eval(num1+operação+num2)
print(resultado)
# Out:
# digite_o_primeiro_numero12
# digite_o_segundo_numero12
# digite_o_operador (+,-,* ou /:)+
# 24

# %%
#Acesso com Dupla Validação
#Defina um usuário e senha corretos no código. Leia usuário e senha. Somente se ambos estiverem corretos (usando and), exiba "Login efetuado!". Caso contrário, "Usuário ou senha incorretos."

us = "konama"
senha = 321123
leruser= input("digite usuario")
lercode= int(input("digite senha"))
if leruser == us and lercode == senha:
    print("logiin efetivado")
elif leruser!= us and us:
    print("usuário ou senha incorretos")
# Out:
# digite usuariokonama
# digite senha321123
# logiin efetivado

# %%
#09
#Triângulo Válido Leia três lados. Valide primeiro se todos são maiores que zero. Em seguida, verifique se formam um triângulo (cada lado menor que a soma dos outros dois). Exiba o resultado.
lado1= int(input("digite valor lado do triângulo"))
lado2= int(input("digite outro lado do triângulo"))
lado3= int(input("digite terceiro lado do triângulo"))
if lado1 and lado2 and lado3 == 0:
    print("inválido")
elif lado1 < lado2+lado3:
    print("forma um triângulo")
elif lado2 < lado1+lado3:
    print("forma um trinângulo")
elif lado3 < lado1+lado2:
    print("forma triângulo")
else:
    print("não forma trinângulo")
# Out:
# digite valor lado do triângulo40
# digite outro lado do triângulo70
# digite terceiro lado do triângulo40
# forma um triângulo

# %%
#Desconto por Faixa de Compra
#Leia o valor de uma compra. Valide que é positivo. Aplique: ≥ R$500 → 15%, ≥ R$200 → 10%, ≥ R$100 → 5%, abaixo → 0%. Exiba o desconto e o valor final
compra = int(input("digite o valor da compra"))
if compra < 0:
    print("valor inválido")
elif compra >= 500:
    desconto=0.15
elif compra >= 200:
    desconto=0.10
elif compra >= 100:
    desconto= 0.05
elif 0 >= compra:
    desconto= 0.00

valor= compra * desconto
print(f"Valor final da compra pós desconto elegível é de : R${compra-valor}")
# Out:
# digite o valor da compra500
# Valor final da compra pós desconto elegível é de : R$425.0

# %%
#Estação do Ano
#Leia o número do mês (1 a 12). Use elif para exibir a estação do ano correspondente. Use or para agrupar os meses de cada estação. Valide o mês (1 a 12).
mes= int(input("digite o numero do mês"))
if mes == 12 or mes == 1 or mes == 2:
    print("verão")
elif mes == 3 or mes == 4 or mes == 5:
    print("outono")
elif mes == 6 or mes == 7 or mes == 8:
    print("inverno")
elif mes == 9 or mes == 10 or mes == 11:
    print("primavera")
else:
    print("mes inválido")
# Out:
# digite o numero do mês4
# outono

# %%
#Número no Intervalo
#Leia dois números A e B (A menor que B) e um terceiro número N. Verifique se N está dentro do intervalo [A, B] usando encadeamento de comparações (A <= N <= B).
A=  int(input("digite numero"))
B= int(input("digite numero maior que B"))
N= int(input("digite numero"))
if A <= N <= B:
    print("N está dentro do conjunto A e B")
else:
    print("N não pertence ao conjunto")
# Out:
# digite numero3
# digite numero maior que B6
# digite numero4
# N está dentro do conjunto A e B

# %%
#Tipo de Número Leia um número inteiro. Usando elif, classifique em: positivo e par, positivo e ímpar, negativo e par, negativo e ímpar, ou zero. Use o operador % para verificar paridade.
num = int(input("digite numero inteiro"))
if num > 0 and num % 2 == 0:
    print("numero par e positivo")
elif num > 0 and num % 2 != 0:
    print("numero positivo  e impar")
elif num < 0 and num % 2 != 0:
    print("numero negativo e impar")
elif num < o and num % 2 == 0:
    print("numero negativo par")2
else:
    print("numero inválido")
# Out:
# digite numero inteiro23
# numero positivo  e impar

# %%
#Aprovação com Frequência
#Leia a nota (0-10) e a frequência (0-100%) de um aluno. Use and para verificar aprovação: nota ≥ 7 e frequência ≥ 75%. Se apenas um critério falhar, indique qual. Se ambos falharem, exiba "Reprovado em nota e frequência".
nota = int(input("digite nota de 0 a 10"))
frequencia = int(input("frequencia do aluno"))
if nota >= 7 and frequencia >= 75:
    print("aprovado")
elif 7 >= nota and frequencia >= 75:
    print("reprovado em nota")
elif 7 >= nota and frequencia <= 75:
    print("reprovado em frequencia e nota")
else:
    print|("numero inválido")
# Out:
# digite nota de 0 a 105
# frequencia do aluno10
# reprovado em frequencia e nota

# %%
#IMC Simplificado
#Leia peso (kg) e altura (m). Valide que peso > 0 e 0.5 <= altura <= 2.5. Calcule o IMC. Classifique em: Abaixo do peso (<18.5), Normal (18.5–24.9), Sobrepeso (25–29.9) e Obesidade (≥30). Exiba o IMC com 2 casas decimais e a classificação.
peso = float(input("peso"))
altura = float(input("altura"))

if peso > 0 and 0.5 <= altura <= 2.5:
    imc = peso / (altura ** 2)
    if imc < 18.5:
        classificação= "abaixo do peso"
    elif imc <25:
        classificação ="normal"
    elif imc < 30:
        classificação= "sobrepeso"
    else:
        classificação= "obesidade"

    print(f"imc= {imc:.2f}")
    print(classificação)
else:
    print("Valores inválidos")
# Out:
# peso50
# altura1.75
# imc= 16.33
# abaixo do peso
